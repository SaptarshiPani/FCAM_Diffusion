# %%
import torch
import torch.nn as nn
import torch.fft as fft
import torch.distributions as dist
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms
import torchvision
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import os
from PIL import Image

class FFTBlock(nn.Module):
    def __init__(self, channels):
        super(FFTBlock, self).__init__()
        # FFT feature processing layers
        self.fft_conv = nn.Sequential(
            nn.Conv2d(channels * 2, channels, kernel_size=1),
            nn.BatchNorm2d(channels),
            nn.ReLU(),
            nn.Conv2d(channels, channels, kernel_size=1)
        )
    
    def forward(self, x):
        # Perform 2D FFT
        fft_x = torch.fft.fft2(x, dim=(-2, -1))
        
        # Compute magnitude and phase
        fft_mag = torch.abs(fft_x)
        fft_phase = torch.angle(fft_x)
        
        # Concatenate magnitude and phase
        fft_features = torch.cat([fft_mag, fft_phase], dim=1)
        
        # Process FFT features
        fft_processed = self.fft_conv(fft_features)
        
        return fft_processed

class UNet(nn.Module):
    def __init__(self, input_channels=4, output_channels=1):
        super(UNet, self).__init__()
        
        # Encoder
        self.enc1 = self.conv_block(input_channels, 64)
        self.enc2 = self.conv_block(64, 128)
        self.enc3 = self.conv_block(128, 256)
        self.enc4 = self.conv_block(256, 512)
        
        # FFT Blocks for each encoder level
        self.fft1 = FFTBlock(64)
        self.fft2 = FFTBlock(128)
        self.fft3 = FFTBlock(256)
        self.fft4 = FFTBlock(512)
        
        # Bottleneck
        self.bottleneck = self.conv_block(512, 1024)
        self.fft_bottleneck = FFTBlock(1024)
        
        # Decoder
        self.up4 = self.upconv(1024, 512)
        self.dec4 = self.conv_block(1024, 512)
        
        self.up3 = self.upconv(512, 256)
        self.dec3 = self.conv_block(512, 256)
        
        self.up2 = self.upconv(256, 128)
        self.dec2 = self.conv_block(256, 128)
        
        self.up1 = self.upconv(128, 64)
        self.dec1 = self.conv_block(128, 64)
        
        self.final = nn.Conv2d(64, 3, kernel_size=3, padding=1)
        self.final2 = nn.Conv2d(3, output_channels, kernel_size=1)
        self.out_act = nn.Sigmoid()
        
    def conv_block(self, in_channels, out_channels):
        return nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
        )
    
    def upconv(self, in_channels, out_channels):
        return nn.ConvTranspose2d(in_channels, out_channels, kernel_size=2, stride=2)
    
    def forward(self, x, condition):
        # Concatenate condition with input (conditioning)
        y = torch.cat((x, condition), dim=1)
        
        # Encoder
        enc1 = self.enc1(y)
        # Apply FFT processing
        enc1_fft = self.fft1(enc1)
        enc1 = enc1 + enc1_fft
        
        enc2 = self.enc2(F.max_pool2d(enc1, 2))
        enc2_fft = self.fft2(enc2)
        enc2 = enc2 + enc2_fft
        
        enc3 = self.enc3(F.max_pool2d(enc2, 2))
        enc3_fft = self.fft3(enc3)
        enc3 = enc3 + enc3_fft
        
        enc4 = self.enc4(F.max_pool2d(enc3, 2))
        enc4_fft = self.fft4(enc4)
        enc4 = enc4 + enc4_fft
        
        # Bottleneck
        bottleneck = self.bottleneck(F.max_pool2d(enc4, 2))
        bottleneck_fft = self.fft_bottleneck(bottleneck)
        bottleneck = bottleneck + bottleneck_fft
        
        # Decoder
        up4 = self.up4(bottleneck)
        dec4 = self.dec4(torch.cat((up4, enc4), dim=1))
        
        up3 = self.up3(dec4)
        dec3 = self.dec3(torch.cat((up3, enc3), dim=1))
        
        up2 = self.up2(dec3)
        dec2 = self.dec2(torch.cat((up2, enc2), dim=1))
        
        up1 = self.up1(dec2)
        dec1 = self.dec1(torch.cat((up1, enc1), dim=1))
        
        return self.out_act(self.final2(x - self.final(dec1)))

class FrequencyNoiseReduction:
    @staticmethod
    def reduce_noise(x, threshold_ratio=0.1):
        """
        Reduce noise in the frequency domain ```python
        using a simple thresholding method.
        """
        # Perform 2D FFT
        f_transform = torch.fft.fft2(x)
        
        # Compute magnitude
        magnitude = torch.abs(f_transform)
        
        # Create a mask to suppress high-frequency components
        threshold = threshold_ratio * torch.max(magnitude)
        mask = magnitude > threshold
        
        # Apply the mask
        f_transform_filtered = f_transform * mask
        
        # Inverse FFT to get back to spatial domain
        x_filtered = torch.fft.ifft2(f_transform_filtered).real
        
        return x_filtered

class Diffusion:
    def __init__(self, T=1000, beta_start=1e-4, beta_end=0.02, device=False):
        self.device = device
        self.T = T
        self.betas = torch.linspace(beta_start, beta_end, T)
        self.alphas = 1.0 - self.betas
        self.alpha_hat = torch.cumprod(self.alphas, dim=0).to(device)
    
    def q_sample(self, x_start, t, noise=None):
        """Add noise to input at timestep t."""
        if noise is None:
            noise = torch.randn_like(x_start)
        sqrt_alpha_hat = torch.sqrt(self.alpha_hat[t])[:, None, None, None]
        sqrt_one_minus_alpha_hat = torch.sqrt(1 - self.alpha_hat[t])[:, None, None, None]
        return sqrt_alpha_hat * x_start + sqrt_one_minus_alpha_hat * noise, noise

class SegmentationDataset(Dataset):
    def __init__(self, image_dir, mask_dir, transform=None, target_transform=None):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.image_filenames = sorted(os.listdir(image_dir))
        self.mask_filenames = sorted(os.listdir(mask_dir))
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.image_filenames)

    def __getitem__(self, idx):
        image_path = os.path.join(self.image_dir, self.image_filenames[idx])
        mask_path = os.path.join(self.mask_dir, self.mask_filenames[idx])
        
        image = Image.open(image_path).convert("RGB")
        mask = Image.open(mask_path).convert("L")
        
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            mask = self.target_transform(mask)
        
        return image, mask

# Define transformations for images and masks
image_transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

mask_transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
])

# Paths to dataset folders
train_image_dir = "/kaggle/input/cpm15-cpm17-kumar/cpm_15_17_kumar_Final/cpm17/train/images"
train_mask_dir = "/kaggle/input/cpm15-cpm17-kumar/cpm_15_17_kumar_Final/cpm17/train/masks"
val_image_dir = "/kaggle/input/cpm15-cpm17-kumar/cpm_15_17_kumar_Final/cpm17/validation/images"
val_mask_dir = "/kaggle/input/cpm15-cpm17-kumar/cpm_15_17_kumar_Final/cpm17/validation/masks"

test_image_dir = "/kaggle/input/cpm15-cpm17-kumar/cpm_15_17_kumar_Final/cpm17/test/images"
test_mask_dir = "/kaggle/input/cpm15-cpm17-kumar/cpm_15_17_kumar_Final/cpm17/test/masks"

# Create dataset objects
train_dataset = SegmentationDataset(train_image_dir, train_mask_dir, 
                                    transform=image_transform, 
                                    target_transform=mask_transform)
val_dataset = SegmentationDataset(val_image_dir, val_mask_dir, 
                                  transform=image_transform, 
                                  target_transform=mask_transform)

test_dataset = SegmentationDataset(test_image_dir, test_mask_dir, 
                                   transform=image_transform, 
                                   target_transform=mask_transform)

# DataLoaders
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=4, shuffle=False, num_workers=2)

# Check a sample batch
if __name__ == "__main__":
    for images, masks in train_loader:
        print("Image batch shape:", images.shape)
        print("Mask batch shape:", masks.shape)
        break

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = UNet(input_channels=4, output_channels=1).to(device)
diffusion = Diffusion(T=1, device=device)

# Loss and optimizer
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# Metric Calculation Function
def calculate_metrics(pred, target):
    pred = (pred > 0.5).float()  # Binarize predictions (threshold = 0.5)
    target = target.float()
    
    intersection = torch.sum(pred * target)
    union = torch.sum(pred) + torch.sum(target) - intersection
    dice = (2.0 * intersection) / (torch.sum(pred) + torch.sum(target) + 1e-8)
    
    true_positive = torch.sum(pred * target)
    false_positive = torch.sum(pred * (1 - target))
    false_negative = torch.sum((1 - pred) * target)
    
    accuracy = torch.sum(pred == target) / torch.numel(target)
    precision = true_positive / (true_positive + false_positive + 1e-8)
    recall = true_positive / (true_positive + false_negative + 1e-8)
    
    iou = intersection / (union + 1e-8)  # Avoid division by zero
    
    return iou.item(), dice.item(), accuracy.item(), precision.item(), recall.item()




import torch
from tqdm import tqdm

import matplotlib.pyplot as plt

# Combined Training and Validation Loop with loss and dice score tracking
def train_and_validate_model(num_epochs):
    best_val_dice = 0
    train_losses = []
    val_losses = []
    train_dices = []
    val_dices = []

    for epoch in range(num_epochs):
        # Training Phase
        model.train()
        train_loss = 0
        train_metrics = {"iou": 0, "dice": 0, "accuracy": 0, "precision": 0, "recall": 0}
        train_count = 0

        for images, masks in tqdm(train_loader, desc=f"Epoch {epoch + 1} - Training"):
            images, masks = images.to(device), masks.to(device, dtype=torch.float)
            t = torch.randint(0, diffusion.T, (images.size(0),), device=device)
            noisy_images, noise = diffusion.q_sample(images, t)
            filtered_images = FrequencyNoiseReduction.reduce_noise(noisy_images)
            noise_pred = model(filtered_images, masks)

            loss = criterion(noise_pred, masks)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

            # Calculate training metrics
            iou, dice, accuracy, precision, recall = calculate_metrics(noise_pred, masks)
            train_metrics["iou"] += iou
            train_metrics["dice"] += dice
            train_metrics["accuracy"] += accuracy
            train_metrics["precision"] += precision
            train_metrics["recall"] += recall
            train_count += 1

        train_loss /= len(train_loader)
        train_metrics = {k: v / train_count for k, v in train_metrics.items()}
        train_losses.append(train_loss)
        train_dices.append(train_metrics['dice'])

        # Validation Phase
        model.eval()
        val_loss = 0
        val_metrics = {"iou": 0, "dice": 0, "accuracy": 0, "precision": 0, "recall": 0}
        val_count = 0

        with torch.no_grad():
            for images, masks in tqdm(val_loader, desc=f"Epoch {epoch + 1} - Validation"):
                images, masks = images.to(device), masks.to(device, dtype=torch.float)
                predictions = model(images, masks)
                loss = criterion(predictions, masks)
                val_loss += loss.item()

                # Calculate validation metrics
                iou, dice, accuracy, precision, recall = calculate_metrics(predictions, masks)
                val_metrics["iou"] += iou
                val_metrics["dice"] += dice
                val_metrics["accuracy"] += accuracy
                val_metrics["precision"] += precision
                val_metrics["recall"] += recall
                val_count += 1

        val_loss /= len(val_loader)
        val_metrics = {k: v / val_count for k, v in val_metrics.items()}
        val_losses.append(val_loss)
        val_dices.append(val_metrics['dice'])

        print("\nEpoch {} Summary: Train Loss: {:.4f}, Val Loss: {:.4f}, "
              "Train Accuracy: {:.4f}, Val Accuracy: {:.4f}, "
              "Train IoU: {:.4f}, Val IoU: {:.4f}, "
              "Train Dice: {:.4f}, Val Dice: {:.4f}, "
              "Train Precision: {:.4f}, Val Precision: {:.4f}, "
              "Train Recall: {:.4f}, Val Recall: {:.4f}".format(
              epoch + 1, train_loss, val_loss,
              train_metrics['accuracy'], val_metrics['accuracy'],
              train_metrics['iou'], val_metrics['iou'],
              train_metrics['dice'], val_metrics['dice'],
              train_metrics['precision'], val_metrics['precision'],
              train_metrics['recall'], val_metrics['recall']
        ))

        # Save the best model
        if val_metrics["dice"] > best_val_dice:
            best_val_dice = val_metrics["dice"]
            torch.save(model.state_dict(), "best_model.pth")
            print(f"Saved Best Model with Dice: {best_val_dice:.4f}")

    # Return the loss and dice scores for plotting
    return train_losses, val_losses, train_dices, val_dices

def plot_training_curves(train_losses, val_losses, train_dices, val_dices):
    # Plot Train/Validation Loss and Dice Score Curves
    epochs = range(1, len(train_losses) + 1)
    
    # Plot Loss Curve
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss')
    plt.plot(epochs, val_losses, label='Validation Loss')
    plt.title('Train and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plot Dice Score Curve
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_dices, label='Train Dice')
    plt.plot(epochs, val_dices, label='Validation Dice')
    plt.title('Train and Validation Dice Score')
    plt.xlabel('Epochs')
    plt.ylabel('Dice Score')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Run Training and Validation
if __name__ == "__main__":
    # Capture the returned values for loss and dice score curves
    train_losses, val_losses, train_dices, val_dices = train_and_validate_model(num_epochs=200)

    # Plot the training curves
    plot_training_curves(train_losses, val_losses, train_dices, val_dices)






# Evaluation function
def evaluate(model, dataloader, criterion, diffusion, device, visualize=False):
    model.eval()
    total_loss = 0
    
    # Initialize metrics
    total_iou, total_dice = 0, 0
    total_accuracy, total_precision, total_recall = 0, 0, 0
    num_batches = 0
    
    with torch.no_grad():
        for images, masks in tqdm(dataloader, desc="Evaluating"):
            images, masks = images.to(device), masks.to(device, dtype=torch.float)
            
            # Sample timestep
            t = torch.randint(0, diffusion.T, (images.size(0),), device=device)

            # Add noise to images
            noisy_images, noise = diffusion.q_sample(images, t)

            # Apply frequency noise reduction
            filtered_images = FrequencyNoiseReduction.reduce_noise(noisy_images)

            # Predict noise conditioned on masks
            noise_pred = model(filtered_images, masks)

            # Compute loss
            loss = criterion(noise_pred, masks)
            total_loss += loss.item()

            # Calculate metrics
            iou, dice, accuracy, precision, recall = calculate_metrics(noise_pred, masks)
            total_iou += iou
            total_dice += dice
            total_accuracy += accuracy
            total_precision += precision
            total_recall += recall
            num_batches += 1

            # Visualization for the first batch
            if visualize and num_batches == 1:
                sample_images = images.cpu()
                noisy_sample_images = noisy_images.cpu()
                generated_images = noise_pred.cpu()
                sample_masks = masks.cpu()

                # Plot a few examples
                fig, axes = plt.subplots(4, 4, figsize=(12, 12))
                for i in range(4):  # Show 4 samples
                    axes[i, 0].imshow(sample_images[i, 0])
                    axes[i, 0].set_title("Input Image")
                    axes[i, 1].imshow(noisy_sample_images[i, 0])
                    axes[i, 1].set_title("Noisy Image")
                    axes[i, 2].imshow(generated_images[i, 0])
                    axes[i, 2].set_title("Predicted Mask")
                    axes[i, 3].imshow(sample_masks[i, 0])
                    axes[i, 3].set_title("Ground Truth Mask")

                    # Hide axes
                    for j in range(4):
                        axes[i, j].axis('off')

                plt.tight_layout()
                plt.show()

    # Compute average metrics
    average_loss = total_loss / num_batches
    average_iou = total_iou / num_batches
    average_dice = total_dice / num_batches
    average_accuracy = total_accuracy / num_batches
    average_precision = total_precision / num_batches
    total_precision / num_batches
    average_recall = total_recall / num_batches

    print(f"Average Evaluation Loss: {average_loss:.4f}")
    print(f"Average IoU: {average_iou:.4f}")
    print(f"Average Dice Coefficient: {average_dice:.4f}")
    print(f"Average Accuracy: {average_accuracy:.4f}")
    print(f"Average Precision: {average_precision:.4f}")
    print(f"Average Recall: {average_recall:.4f}")
    
    return {
        "loss": average_loss,
        "iou": average_iou,
        "dice": average_dice,
        "accuracy": average_accuracy,
        "precision": average_precision,
        "recall": average_recall
    }

# Perform evaluation with visualization
metrics = evaluate(model, test_loader, criterion, diffusion, device, visualize=True)
# Out:
# Image batch shape: torch.Size([4, 3, 128, 128])
# Mask batch shape: torch.Size([4, 1, 128, 128])
# Epoch 1 - Training: 100%|██████████| 7/7 [00:03<00:00,  1.89it/s]
# Epoch 1 - Validation: 100%|██████████| 2/2 [00:00<00:00,  7.52it/s]
# Epoch 1 Summary: Train Loss: 0.3440, Val Loss: 0.5006, Train Accuracy: 0.7362, Val Accuracy: 0.5782, Train IoU: 0.6806, Val IoU: 0.0000, Train Dice: 0.7844, Val Dice: 0.0000, Train Precision: 0.8269, Val Precision: 0.0000, Train Recall: 0.7824, Val Recall: 0.0000
# Epoch 2 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.95it/s]
# Epoch 2 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.65it/s]
# Epoch 2 Summary: Train Loss: 0.1587, Val Loss: 0.3577, Train Accuracy: 0.7650, Val Accuracy: 0.6353, Train IoU: 0.8024, Val IoU: 0.2611, Train Dice: 0.8900, Val Dice: 0.4130, Train Precision: 0.8972, Val Precision: 0.9907, Train Recall: 0.8836, Val Recall: 0.2618
# Saved Best Model with Dice: 0.4130
# Epoch 3 - Training: 100%|██████████| 7/7 [00:00<00:00,  9.18it/s]
# Epoch 3 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.88it/s]
# Epoch 3 Summary: Train Loss: 0.1202, Val Loss: 0.3425, Train Accuracy: 0.7564, Val Accuracy: 0.6445, Train IoU: 0.7978, Val IoU: 0.3086, Train Dice: 0.8874, Val Dice: 0.4714, Train Precision: 0.8918, Val Precision: 0.9899, Train Recall: 0.8859, Val Recall: 0.3096
# Saved Best Model with Dice: 0.4714
# Epoch 4 - Training: 100%|██████████| 7/7 [00:00<00:00,  9.11it/s]
# Epoch 4 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.43it/s]
# Epoch 4 Summary: Train Loss: 0.1074, Val Loss: 0.2364, Train Accuracy: 0.7637, Val Accuracy: 0.6799, Train IoU: 0.7983, Val IoU: 0.5616, Train Dice: 0.8877, Val Dice: 0.7175, Train Precision: 0.8675, Val Precision: 0.9832, Train Recall: 0.9111, Val Recall: 0.5673
# Saved Best Model with Dice: 0.7175
# Epoch 5 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.90it/s]
# Epoch 5 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.91it/s]
# Epoch 5 Summary: Train Loss: 0.1087, Val Loss: 0.1591, Train Accuracy: 0.7600, Val Accuracy: 0.6825, Train IoU: 0.7909, Val IoU: 0.7442, Train Dice: 0.8830, Val Dice: 0.8532, Train Precision: 0.9126, Val Precision: 0.9214, Train Recall: 0.8584, Val Recall: 0.7946
# Saved Best Model with Dice: 0.8532
# Epoch 6 - Training: 100%|██████████| 7/7 [00:00<00:00,  9.13it/s]
# Epoch 6 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.18it/s]
# Epoch 6 Summary: Train Loss: 0.1029, Val Loss: 0.1441, Train Accuracy: 0.7564, Val Accuracy: 0.6828, Train IoU: 0.8093, Val IoU: 0.7797, Train Dice: 0.8943, Val Dice: 0.8762, Train Precision: 0.8978, Val Precision: 0.8879, Train Recall: 0.8922, Val Recall: 0.8649
# Saved Best Model with Dice: 0.8762
# Epoch 7 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.98it/s]
# Epoch 7 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.94it/s]
# Epoch 7 Summary: Train Loss: 0.0945, Val Loss: 0.1627, Train Accuracy: 0.7762, Val Accuracy: 0.6827, Train IoU: 0.8109, Val IoU: 0.7401, Train Dice: 0.8954, Val Dice: 0.8505, Train Precision: 0.8885, Val Precision: 0.9429, Train Recall: 0.9036, Val Recall: 0.7748
# Epoch 8 - Training: 100%|██████████| 7/7 [00:00<00:00,  9.03it/s]
# Epoch 8 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.47it/s]
# Epoch 8 Summary: Train Loss: 0.0931, Val Loss: 0.1576, Train Accuracy: 0.7762, Val Accuracy: 0.6828, Train IoU: 0.8112, Val IoU: 0.7572, Train Dice: 0.8956, Val Dice: 0.8618, Train Precision: 0.9025, Val Precision: 0.9328, Train Recall: 0.8898, Val Recall: 0.8008
# Epoch 9 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.95it/s]
# Epoch 9 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.30it/s]
# Epoch 9 Summary: Train Loss: 0.1015, Val Loss: 0.1575, Train Accuracy: 0.7527, Val Accuracy: 0.6827, Train IoU: 0.8055, Val IoU: 0.7469, Train Dice: 0.8922, Val Dice: 0.8551, Train Precision: 0.9006, Val Precision: 0.9386, Train Recall: 0.8851, Val Recall: 0.7852
# Epoch 10 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.85it/s]
# Epoch 10 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.27it/s]
# Epoch 10 Summary: Train Loss: 0.0944, Val Loss: 0.1476, Train Accuracy: 0.7651, Val Accuracy: 0.6828, Train IoU: 0.8163, Val IoU: 0.7627, Train Dice: 0.8986, Val Dice: 0.8654, Train Precision: 0.9022, Val Precision: 0.9263, Train Recall: 0.8954, Val Recall: 0.8121
# Epoch 11 - Training: 100%|██████████| 7/7 [00:00<00:00,  9.04it/s]
# Epoch 11 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.91it/s]
# Epoch 11 Summary: Train Loss: 0.0909, Val Loss: 0.1488, Train Accuracy: 0.7710, Val Accuracy: 0.6828, Train IoU: 0.8187, Val IoU: 0.7570, Train Dice: 0.9001, Val Dice: 0.8616, Train Precision: 0.8997, Val Precision: 0.9333, Train Recall: 0.9007, Val Recall: 0.8002
# Epoch 12 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.87it/s]
# Epoch 12 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.55it/s]
# Epoch 12 Summary: Train Loss: 0.0967, Val Loss: 0.1576, Train Accuracy: 0.7600, Val Accuracy: 0.6827, Train IoU: 0.8087, Val IoU: 0.7396, Train Dice: 0.8941, Val Dice: 0.8503, Train Precision: 0.9043, Val Precision: 0.9418, Train Recall: 0.8849, Val Recall: 0.7749
# Epoch 13 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.89it/s]
# Epoch 13 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.91it/s]
# Epoch 13 Summary: Train Loss: 0.0988, Val Loss: 0.1937, Train Accuracy: 0.7500, Val Accuracy: 0.6821, Train IoU: 0.8068, Val IoU: 0.6686, Train Dice: 0.8928, Val Dice: 0.8013, Train Precision: 0.8873, Val Precision: 0.9665, Train Recall: 0.8986, Val Recall: 0.6844
# Epoch 14 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.85it/s]
# Epoch 14 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.75it/s]
# Epoch 14 Summary: Train Loss: 0.1002, Val Loss: 0.1417, Train Accuracy: 0.7527, Val Accuracy: 0.6828, Train IoU: 0.8039, Val IoU: 0.7738, Train Dice: 0.8912, Val Dice: 0.8724, Train Precision: 0.9018, Val Precision: 0.9099, Train Recall: 0.8823, Val Recall: 0.8379
# Epoch 15 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.98it/s]
# Epoch 15 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.72it/s]
# Epoch 15 Summary: Train Loss: 0.0947, Val Loss: 0.1497, Train Accuracy: 0.7600, Val Accuracy: 0.6828, Train IoU: 0.8134, Val IoU: 0.7560, Train Dice: 0.8970, Val Dice: 0.8610, Train Precision: 0.8966, Val Precision: 0.9306, Train Recall: 0.8977, Val Recall: 0.8011
# Epoch 16 - Training: 100%|██████████| 7/7 [00:00<00:00,  9.01it/s]
# Epoch 16 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.56it/s]
# Epoch 16 Summary: Train Loss: 0.0903, Val Loss: 0.1378, Train Accuracy: 0.7732, Val Accuracy: 0.6828, Train IoU: 0.8113, Val IoU: 0.7865, Train Dice: 0.8957, Val Dice: 0.8804, Train Precision: 0.9030, Val Precision: 0.8918, Train Recall: 0.8896, Val Recall: 0.8696
# Saved Best Model with Dice: 0.8804
# Epoch 17 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.52it/s]
# Epoch 17 - Validation: 100%|██████████| 2/2 [00:00<00:00,  9.56it/s]
# Epoch 17 Summary: Train Loss: 0.0970, Val Loss: 0.1835, Train Accuracy: 0.7553, Val Accuracy: 0.6819, Train IoU: 0.8116, Val IoU: 0.6896, Train Dice: 0.8959, Val Dice: 0.8161, Train Precision: 0.9043, Val Precision: 0.9595, Train Recall: 0.8884, Val Recall: 0.7102
# Epoch 18 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.94it/s]
# Epoch 18 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.50it/s]
# Epoch 18 Summary: Train Loss: 0.0928, Val Loss: 0.1503, Train Accuracy: 0.7641, Val Accuracy: 0.6828, Train IoU: 0.8190, Val IoU: 0.7528, Train Dice: 0.9002, Val Dice: 0.8590, Train Precision: 0.9001, Val Precision: 0.9325, Train Recall: 0.9007, Val Recall: 0.7963
# Epoch 19 - Training: 100%|██████████| 7/7 [00:00<00:00,  9.06it/s]
# Epoch 19 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.50it/s]
# Epoch 19 Summary: Train Loss: 0.0966, Val Loss: 0.1635, Train Accuracy: 0.7527, Val Accuracy: 0.6827, Train IoU: 0.8111, Val IoU: 0.7279, Train Dice: 0.8954, Val Dice: 0.8425, Train Precision: 0.8933, Val Precision: 0.9450, Train Recall: 0.8979, Val Recall: 0.7600
# Epoch 20 - Training: 100%|██████████| 7/7 [00:00<00:00,  9.11it/s]
# Epoch 20 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.51it/s]
# Epoch 20 Summary: Train Loss: 0.0904, Val Loss: 0.1658, Train Accuracy: 0.7710, Val Accuracy: 0.6826, Train IoU: 0.8132, Val IoU: 0.7223, Train Dice: 0.8967, Val Dice: 0.8387, Train Precision: 0.9043, Val Precision: 0.9435, Train Recall: 0.8899, Val Recall: 0.7549
# Epoch 21 - Training: 100%|██████████| 7/7 [00:00<00:00,  9.08it/s]
# Epoch 21 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.55it/s]
# Epoch 21 Summary: Train Loss: 0.0936, Val Loss: 0.1472, Train Accuracy: 0.7610, Val Accuracy: 0.6828, Train IoU: 0.8071, Val IoU: 0.7617, Train Dice: 0.8929, Val Dice: 0.8647, Train Precision: 0.8967, Val Precision: 0.9243, Train Recall: 0.8896, Val Recall: 0.8122
# Epoch 22 - Training: 100%|██████████| 7/7 [00:00<00:00,  9.10it/s]
# Epoch 22 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.29it/s]
# Epoch 22 Summary: Train Loss: 0.0881, Val Loss: 0.1400, Train Accuracy: 0.7725, Val Accuracy: 0.6828, Train IoU: 0.8151, Val IoU: 0.7779, Train Dice: 0.8981, Val Dice: 0.8751, Train Precision: 0.9075, Val Precision: 0.9099, Train Recall: 0.8890, Val Recall: 0.8428
# Epoch 23 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.90it/s]
# Epoch 23 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.87it/s]
# Epoch 23 Summary: Train Loss: 0.0967, Val Loss: 0.1428, Train Accuracy: 0.7521, Val Accuracy: 0.6828, Train IoU: 0.8119, Val IoU: 0.7686, Train Dice: 0.8961, Val Dice: 0.8691, Train Precision: 0.9030, Val Precision: 0.9224, Train Recall: 0.8898, Val Recall: 0.8217
# Epoch 24 - Training: 100%|██████████| 7/7 [00:00<00:00,  9.09it/s]
# Epoch 24 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.87it/s]
# Epoch 24 Summary: Train Loss: 0.0955, Val Loss: 0.1527, Train Accuracy: 0.7553, Val Accuracy: 0.6827, Train IoU: 0.8141, Val IoU: 0.7473, Train Dice: 0.8974, Val Dice: 0.8554, Train Precision: 0.8956, Val Precision: 0.9375, Train Recall: 0.8998, Val Recall: 0.7865
# Epoch 25 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.90it/s]
# Epoch 25 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.30it/s]
# Epoch 25 Summary: Train Loss: 0.0953, Val Loss: 0.1396, Train Accuracy: 0.7546, Val Accuracy: 0.6828, Train IoU: 0.8154, Val IoU: 0.7730, Train Dice: 0.8981, Val Dice: 0.8720, Train Precision: 0.9010, Val Precision: 0.9184, Train Recall: 0.8955, Val Recall: 0.8301
# Epoch 26 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.91it/s]
# Epoch 26 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.34it/s]
# Epoch 26 Summary: Train Loss: 0.0877, Val Loss: 0.1474, Train Accuracy: 0.7725, Val Accuracy: 0.6828, Train IoU: 0.8124, Val IoU: 0.7566, Train Dice: 0.8964, Val Dice: 0.8614, Train Precision: 0.9074, Val Precision: 0.9312, Train Recall: 0.8858, Val Recall: 0.8014
# Epoch 27 - Training: 100%|██████████| 7/7 [00:00<00:00,  9.10it/s]
# Epoch 27 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.41it/s]
# Epoch 27 Summary: Train Loss: 0.0877, Val Loss: 0.1592, Train Accuracy: 0.7727, Val Accuracy: 0.6826, Train IoU: 0.8093, Val IoU: 0.7401, Train Dice: 0.8945, Val Dice: 0.8506, Train Precision: 0.8955, Val Precision: 0.9368, Train Recall: 0.8936, Val Recall: 0.7792
# Epoch 28 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.94it/s]
# Epoch 28 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.62it/s]
# Epoch 28 Summary: Train Loss: 0.0948, Val Loss: 0.1473, Train Accuracy: 0.7521, Val Accuracy: 0.6827, Train IoU: 0.8135, Val IoU: 0.7610, Train Dice: 0.8971, Val Dice: 0.8643, Train Precision: 0.9018, Val Precision: 0.9266, Train Recall: 0.8925, Val Recall: 0.8099
# Epoch 29 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.84it/s]
# Epoch 29 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.81it/s]
# Epoch 29 Summary: Train Loss: 0.0867, Val Loss: 0.1401, Train Accuracy: 0.7725, Val Accuracy: 0.6828, Train IoU: 0.8166, Val IoU: 0.7780, Train Dice: 0.8990, Val Dice: 0.8751, Train Precision: 0.9063, Val Precision: 0.9100, Train Recall: 0.8918, Val Recall: 0.8430
# Epoch 30 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.93it/s]
# Epoch 30 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.43it/s]
# Epoch 30 Summary: Train Loss: 0.0915, Val Loss: 0.1382, Train Accuracy: 0.7600, Val Accuracy: 0.6828, Train IoU: 0.8139, Val IoU: 0.7839, Train Dice: 0.8972, Val Dice: 0.8789, Train Precision: 0.9003, Val Precision: 0.9010, Train Recall: 0.8944, Val Recall: 0.8580
# Epoch 31 - Training: 100%|██████████| 7/7 [00:00<00:00,  9.00it/s]
# Epoch 31 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.79it/s]
# Epoch 31 Summary: Train Loss: 0.0869, Val Loss: 0.1367, Train Accuracy: 0.7744, Val Accuracy: 0.6828, Train IoU: 0.8095, Val IoU: 0.7808, Train Dice: 0.8946, Val Dice: 0.8769, Train Precision: 0.8961, Val Precision: 0.9131, Train Recall: 0.8932, Val Recall: 0.8435
# Epoch 32 - Training: 100%|██████████| 7/7 [00:00<00:00,  9.00it/s]
# Epoch 32 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.59it/s]
# Epoch 32 Summary: Train Loss: 0.0955, Val Loss: 0.1411, Train Accuracy: 0.7500, Val Accuracy: 0.6828, Train IoU: 0.8062, Val IoU: 0.7679, Train Dice: 0.8926, Val Dice: 0.8687, Train Precision: 0.8992, Val Precision: 0.9272, Train Recall: 0.8865, Val Recall: 0.8171
# Epoch 33 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.86it/s]
# Epoch 33 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.31it/s]
# Epoch 33 Summary: Train Loss: 0.0899, Val Loss: 0.1377, Train Accuracy: 0.7641, Val Accuracy: 0.6828, Train IoU: 0.8191, Val IoU: 0.7783, Train Dice: 0.9003, Val Dice: 0.8753, Train Precision: 0.9073, Val Precision: 0.9186, Train Recall: 0.8933, Val Recall: 0.8360
# Epoch 34 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.94it/s]
# Epoch 34 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.40it/s]
# Epoch 34 Summary: Train Loss: 0.0900, Val Loss: 0.1403, Train Accuracy: 0.7641, Val Accuracy: 0.6828, Train IoU: 0.8209, Val IoU: 0.7770, Train Dice: 0.9013, Val Dice: 0.8745, Train Precision: 0.9051, Val Precision: 0.9169, Train Recall: 0.8979, Val Recall: 0.8359
# Epoch 35 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.90it/s]
# Epoch 35 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.34it/s]
# Epoch 35 Summary: Train Loss: 0.0871, Val Loss: 0.1390, Train Accuracy: 0.7730, Val Accuracy: 0.6828, Train IoU: 0.8124, Val IoU: 0.7749, Train Dice: 0.8964, Val Dice: 0.8732, Train Precision: 0.8985, Val Precision: 0.9205, Train Recall: 0.8946, Val Recall: 0.8305
# Epoch 36 - Training: 100%|██████████| 7/7 [00:00<00:00,  9.00it/s]
# Epoch 36 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.33it/s]
# Epoch 36 Summary: Train Loss: 0.0873, Val Loss: 0.1555, Train Accuracy: 0.7710, Val Accuracy: 0.6826, Train IoU: 0.8172, Val IoU: 0.7432, Train Dice: 0.8991, Val Dice: 0.8527, Train Precision: 0.9025, Val Precision: 0.9414, Train Recall: 0.8962, Val Recall: 0.7792
# Epoch 37 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.83it/s]
# Epoch 37 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.08it/s]
# Epoch 37 Summary: Train Loss: 0.0941, Val Loss: 0.1508, Train Accuracy: 0.7546, Val Accuracy: 0.6827, Train IoU: 0.8141, Val IoU: 0.7595, Train Dice: 0.8972, Val Dice: 0.8633, Train Precision: 0.9036, Val Precision: 0.9312, Train Recall: 0.8913, Val Recall: 0.8047
# Epoch 38 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.62it/s]
# Epoch 38 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.42it/s]
# Epoch 38 Summary: Train Loss: 0.0913, Val Loss: 0.1475, Train Accuracy: 0.7600, Val Accuracy: 0.6827, Train IoU: 0.8123, Val IoU: 0.7558, Train Dice: 0.8962, Val Dice: 0.8609, Train Precision: 0.9010, Val Precision: 0.9348, Train Recall: 0.8915, Val Recall: 0.7978
# Epoch 39 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.85it/s]
# Epoch 39 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.70it/s]
# Epoch 39 Summary: Train Loss: 0.1017, Val Loss: 0.1472, Train Accuracy: 0.7356, Val Accuracy: 0.6828, Train IoU: 0.8043, Val IoU: 0.7586, Train Dice: 0.8910, Val Dice: 0.8627, Train Precision: 0.8944, Val Precision: 0.9342, Train Recall: 0.8877, Val Recall: 0.8013
# Epoch 40 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.84it/s]
# Epoch 40 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.57it/s]
# Epoch 40 Summary: Train Loss: 0.0925, Val Loss: 0.1334, Train Accuracy: 0.7564, Val Accuracy: 0.6828, Train IoU: 0.8156, Val IoU: 0.7882, Train Dice: 0.8983, Val Dice: 0.8815, Train Precision: 0.9036, Val Precision: 0.9052, Train Recall: 0.8932, Val Recall: 0.8590
# Saved Best Model with Dice: 0.8815
# Epoch 41 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.89it/s]
# Epoch 41 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.54it/s]
# Epoch 41 Summary: Train Loss: 0.0934, Val Loss: 0.1322, Train Accuracy: 0.7546, Val Accuracy: 0.6828, Train IoU: 0.8173, Val IoU: 0.7945, Train Dice: 0.8993, Val Dice: 0.8854, Train Precision: 0.9043, Val Precision: 0.8899, Train Recall: 0.8944, Val Recall: 0.8811
# Saved Best Model with Dice: 0.8854
# Epoch 42 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.91it/s]
# Epoch 42 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.34it/s]
# Epoch 42 Summary: Train Loss: 0.0862, Val Loss: 0.1453, Train Accuracy: 0.7725, Val Accuracy: 0.6827, Train IoU: 0.8161, Val IoU: 0.7671, Train Dice: 0.8986, Val Dice: 0.8681, Train Precision: 0.9061, Val Precision: 0.9285, Train Recall: 0.8915, Val Recall: 0.8151
# Epoch 43 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.56it/s]
# Epoch 43 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.62it/s]
# Epoch 43 Summary: Train Loss: 0.0863, Val Loss: 0.1466, Train Accuracy: 0.7725, Val Accuracy: 0.6828, Train IoU: 0.8156, Val IoU: 0.7616, Train Dice: 0.8982, Val Dice: 0.8647, Train Precision: 0.8993, Val Precision: 0.9327, Train Recall: 0.8974, Val Recall: 0.8059
# Epoch 44 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.77it/s]
# Epoch 44 - Validation: 100%|██████████| 2/2 [00:00<00:00,  9.82it/s]
# Epoch 44 Summary: Train Loss: 0.0910, Val Loss: 0.1358, Train Accuracy: 0.7600, Val Accuracy: 0.6828, Train IoU: 0.8177, Val IoU: 0.7812, Train Dice: 0.8995, Val Dice: 0.8772, Train Precision: 0.9024, Val Precision: 0.9141, Train Recall: 0.8970, Val Recall: 0.8432
# Epoch 45 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.83it/s]
# Epoch 45 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.37it/s]
# Epoch 45 Summary: Train Loss: 0.0860, Val Loss: 0.1379, Train Accuracy: 0.7732, Val Accuracy: 0.6828, Train IoU: 0.8157, Val IoU: 0.7760, Train Dice: 0.8984, Val Dice: 0.8739, Train Precision: 0.9049, Val Precision: 0.9214, Train Recall: 0.8922, Val Recall: 0.8309
# Epoch 46 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.90it/s]
# Epoch 46 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.23it/s]
# Epoch 46 Summary: Train Loss: 0.0905, Val Loss: 0.1365, Train Accuracy: 0.7610, Val Accuracy: 0.6828, Train IoU: 0.8095, Val IoU: 0.7803, Train Dice: 0.8946, Val Dice: 0.8766, Train Precision: 0.8982, Val Precision: 0.9171, Train Recall: 0.8914, Val Recall: 0.8395
# Epoch 47 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.80it/s]
# Epoch 47 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.78it/s]
# Epoch 47 Summary: Train Loss: 0.0938, Val Loss: 0.1368, Train Accuracy: 0.7527, Val Accuracy: 0.6828, Train IoU: 0.8080, Val IoU: 0.7802, Train Dice: 0.8937, Val Dice: 0.8765, Train Precision: 0.9006, Val Precision: 0.9152, Train Recall: 0.8873, Val Recall: 0.8410
# Epoch 48 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.70it/s]
# Epoch 48 - Validation: 100%|██████████| 2/2 [00:00<00:00,  9.87it/s]
# Epoch 48 Summary: Train Loss: 0.0858, Val Loss: 0.1363, Train Accuracy: 0.7727, Val Accuracy: 0.6828, Train IoU: 0.8102, Val IoU: 0.7816, Train Dice: 0.8950, Val Dice: 0.8774, Train Precision: 0.9018, Val Precision: 0.9145, Train Recall: 0.8886, Val Recall: 0.8432
# Epoch 49 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.34it/s]
# Epoch 49 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.22it/s]
# Epoch 49 Summary: Train Loss: 0.0862, Val Loss: 0.1444, Train Accuracy: 0.7710, Val Accuracy: 0.6828, Train IoU: 0.8195, Val IoU: 0.7727, Train Dice: 0.9006, Val Dice: 0.8717, Train Precision: 0.9060, Val Precision: 0.9220, Train Recall: 0.8953, Val Recall: 0.8267
# Epoch 50 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.84it/s]
# Epoch 50 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.78it/s]
# Epoch 50 Summary: Train Loss: 0.0860, Val Loss: 0.1333, Train Accuracy: 0.7727, Val Accuracy: 0.6828, Train IoU: 0.8101, Val IoU: 0.7896, Train Dice: 0.8949, Val Dice: 0.8824, Train Precision: 0.9008, Val Precision: 0.9013, Train Recall: 0.8894, Val Recall: 0.8643
# Epoch 51 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.73it/s]
# Epoch 51 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.56it/s]
# Epoch 51 Summary: Train Loss: 0.0936, Val Loss: 0.1374, Train Accuracy: 0.7521, Val Accuracy: 0.6828, Train IoU: 0.8136, Val IoU: 0.7880, Train Dice: 0.8970, Val Dice: 0.8814, Train Precision: 0.9038, Val Precision: 0.9030, Train Recall: 0.8905, Val Recall: 0.8608
# Epoch 52 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.63it/s]
# Epoch 52 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.65it/s]
# Epoch 52 Summary: Train Loss: 0.0929, Val Loss: 0.1489, Train Accuracy: 0.7546, Val Accuracy: 0.6827, Train IoU: 0.8163, Val IoU: 0.7513, Train Dice: 0.8986, Val Dice: 0.8580, Train Precision: 0.8981, Val Precision: 0.9374, Train Recall: 0.8993, Val Recall: 0.7910
# Epoch 53 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.58it/s]
# Epoch 53 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.50it/s]
# Epoch 53 Summary: Train Loss: 0.0921, Val Loss: 0.1343, Train Accuracy: 0.7564, Val Accuracy: 0.6828, Train IoU: 0.8108, Val IoU: 0.7869, Train Dice: 0.8954, Val Dice: 0.8807, Train Precision: 0.9034, Val Precision: 0.9072, Train Recall: 0.8879, Val Recall: 0.8557
# Epoch 54 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.84it/s]
# Epoch 54 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.41it/s]
# Epoch 54 Summary: Train Loss: 0.0934, Val Loss: 0.1346, Train Accuracy: 0.7527, Val Accuracy: 0.6828, Train IoU: 0.8101, Val IoU: 0.7936, Train Dice: 0.8950, Val Dice: 0.8849, Train Precision: 0.9002, Val Precision: 0.8891, Train Recall: 0.8901, Val Recall: 0.8808
# Epoch 55 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.43it/s]
# Epoch 55 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.71it/s]
# Epoch 55 Summary: Train Loss: 0.0889, Val Loss: 0.1343, Train Accuracy: 0.7651, Val Accuracy: 0.6828, Train IoU: 0.8195, Val IoU: 0.7918, Train Dice: 0.9006, Val Dice: 0.8838, Train Precision: 0.9054, Val Precision: 0.8928, Train Recall: 0.8962, Val Recall: 0.8749
# Epoch 56 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.81it/s]
# Epoch 56 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.81it/s]
# Epoch 56 Summary: Train Loss: 0.0934, Val Loss: 0.1321, Train Accuracy: 0.7527, Val Accuracy: 0.6828, Train IoU: 0.8118, Val IoU: 0.7917, Train Dice: 0.8961, Val Dice: 0.8837, Train Precision: 0.9003, Val Precision: 0.8942, Train Recall: 0.8922, Val Recall: 0.8735
# Epoch 57 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.75it/s]
# Epoch 57 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.51it/s]
# Epoch 57 Summary: Train Loss: 0.0998, Val Loss: 0.1439, Train Accuracy: 0.7398, Val Accuracy: 0.6828, Train IoU: 0.8093, Val IoU: 0.7633, Train Dice: 0.8943, Val Dice: 0.8657, Train Precision: 0.9004, Val Precision: 0.9279, Train Recall: 0.8892, Val Recall: 0.8113
# Epoch 58 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.76it/s]
# Epoch 58 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.71it/s]
# Epoch 58 Summary: Train Loss: 0.0855, Val Loss: 0.1493, Train Accuracy: 0.7750, Val Accuracy: 0.6827, Train IoU: 0.8153, Val IoU: 0.7509, Train Dice: 0.8982, Val Dice: 0.8577, Train Precision: 0.9042, Val Precision: 0.9346, Train Recall: 0.8927, Val Recall: 0.7925
# Epoch 59 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.89it/s]
# Epoch 59 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.92it/s]
# Epoch 59 Summary: Train Loss: 0.0860, Val Loss: 0.1435, Train Accuracy: 0.7727, Val Accuracy: 0.6828, Train IoU: 0.8108, Val IoU: 0.7624, Train Dice: 0.8955, Val Dice: 0.8651, Train Precision: 0.8955, Val Precision: 0.9311, Train Recall: 0.8954, Val Recall: 0.8078
# Epoch 60 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.79it/s]
# Epoch 60 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.49it/s]
# Epoch 60 Summary: Train Loss: 0.0926, Val Loss: 0.1353, Train Accuracy: 0.7553, Val Accuracy: 0.6828, Train IoU: 0.8156, Val IoU: 0.7838, Train Dice: 0.8983, Val Dice: 0.8787, Train Precision: 0.9034, Val Precision: 0.9125, Train Recall: 0.8934, Val Recall: 0.8475
# Epoch 61 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.82it/s]
# Epoch 61 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.61it/s]
# Epoch 61 Summary: Train Loss: 0.0855, Val Loss: 0.1372, Train Accuracy: 0.7744, Val Accuracy: 0.6828, Train IoU: 0.8103, Val IoU: 0.7844, Train Dice: 0.8951, Val Dice: 0.8791, Train Precision: 0.9034, Val Precision: 0.9110, Train Recall: 0.8874, Val Recall: 0.8494
# Epoch 62 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.85it/s]
# Epoch 62 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.70it/s]
# Epoch 62 Summary: Train Loss: 0.0966, Val Loss: 0.1542, Train Accuracy: 0.7462, Val Accuracy: 0.6825, Train IoU: 0.8049, Val IoU: 0.7550, Train Dice: 0.8914, Val Dice: 0.8604, Train Precision: 0.8926, Val Precision: 0.9339, Train Recall: 0.8906, Val Recall: 0.7977
# Epoch 63 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.71it/s]
# Epoch 63 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.68it/s]
# Epoch 63 Summary: Train Loss: 0.0854, Val Loss: 0.1373, Train Accuracy: 0.7744, Val Accuracy: 0.6828, Train IoU: 0.8106, Val IoU: 0.7899, Train Dice: 0.8953, Val Dice: 0.8826, Train Precision: 0.9007, Val Precision: 0.8922, Train Recall: 0.8901, Val Recall: 0.8733
# Epoch 64 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.71it/s]
# Epoch 64 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.47it/s]
# Epoch 64 Summary: Train Loss: 0.0942, Val Loss: 0.1428, Train Accuracy: 0.7500, Val Accuracy: 0.6828, Train IoU: 0.8064, Val IoU: 0.7756, Train Dice: 0.8925, Val Dice: 0.8736, Train Precision: 0.8962, Val Precision: 0.9218, Train Recall: 0.8890, Val Recall: 0.8302
# Epoch 65 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.67it/s]
# Epoch 65 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.50it/s]
# Epoch 65 Summary: Train Loss: 0.0846, Val Loss: 0.1373, Train Accuracy: 0.7750, Val Accuracy: 0.6828, Train IoU: 0.8162, Val IoU: 0.7892, Train Dice: 0.8987, Val Dice: 0.8821, Train Precision: 0.9053, Val Precision: 0.9034, Train Recall: 0.8922, Val Recall: 0.8618
# Epoch 66 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.69it/s]
# Epoch 66 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.87it/s]
# Epoch 66 Summary: Train Loss: 0.0899, Val Loss: 0.1337, Train Accuracy: 0.7610, Val Accuracy: 0.6828, Train IoU: 0.8099, Val IoU: 0.7941, Train Dice: 0.8948, Val Dice: 0.8852, Train Precision: 0.8991, Val Precision: 0.8960, Train Recall: 0.8907, Val Recall: 0.8747
# Epoch 67 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.73it/s]
# Epoch 67 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.87it/s]
# Epoch 67 Summary: Train Loss: 0.0858, Val Loss: 0.1361, Train Accuracy: 0.7710, Val Accuracy: 0.6828, Train IoU: 0.8196, Val IoU: 0.7887, Train Dice: 0.9006, Val Dice: 0.8818, Train Precision: 0.9072, Val Precision: 0.9047, Train Recall: 0.8941, Val Recall: 0.8601
# Epoch 68 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.61it/s]
# Epoch 68 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.74it/s]
# Epoch 68 Summary: Train Loss: 0.0936, Val Loss: 0.1330, Train Accuracy: 0.7500, Val Accuracy: 0.6828, Train IoU: 0.8116, Val IoU: 0.7886, Train Dice: 0.8957, Val Dice: 0.8818, Train Precision: 0.8969, Val Precision: 0.9070, Train Recall: 0.8946, Val Recall: 0.8579
# Epoch 69 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.56it/s]
# Epoch 69 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.86it/s]
# Epoch 69 Summary: Train Loss: 0.0880, Val Loss: 0.1322, Train Accuracy: 0.7651, Val Accuracy: 0.6828, Train IoU: 0.8166, Val IoU: 0.7927, Train Dice: 0.8987, Val Dice: 0.8843, Train Precision: 0.9047, Val Precision: 0.9013, Train Recall: 0.8930, Val Recall: 0.8679
# Epoch 70 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.71it/s]
# Epoch 70 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.63it/s]
# Epoch 70 Summary: Train Loss: 0.0899, Val Loss: 0.1322, Train Accuracy: 0.7600, Val Accuracy: 0.6828, Train IoU: 0.8151, Val IoU: 0.7955, Train Dice: 0.8979, Val Dice: 0.8861, Train Precision: 0.9033, Val Precision: 0.8940, Train Recall: 0.8926, Val Recall: 0.8783
# Saved Best Model with Dice: 0.8861
# Epoch 71 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.63it/s]
# Epoch 71 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.50it/s]
# Epoch 71 Summary: Train Loss: 0.0847, Val Loss: 0.1335, Train Accuracy: 0.7744, Val Accuracy: 0.6828, Train IoU: 0.8092, Val IoU: 0.7948, Train Dice: 0.8944, Val Dice: 0.8856, Train Precision: 0.8975, Val Precision: 0.8940, Train Recall: 0.8914, Val Recall: 0.8774
# Epoch 72 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.66it/s]
# Epoch 72 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.35it/s]
# Epoch 72 Summary: Train Loss: 0.0853, Val Loss: 0.1359, Train Accuracy: 0.7727, Val Accuracy: 0.6828, Train IoU: 0.8069, Val IoU: 0.7874, Train Dice: 0.8930, Val Dice: 0.8810, Train Precision: 0.9015, Val Precision: 0.9070, Train Recall: 0.8848, Val Recall: 0.8566
# Epoch 73 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.63it/s]
# Epoch 73 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.45it/s]
# Epoch 73 Summary: Train Loss: 0.0854, Val Loss: 0.1360, Train Accuracy: 0.7730, Val Accuracy: 0.6828, Train IoU: 0.8130, Val IoU: 0.7893, Train Dice: 0.8968, Val Dice: 0.8822, Train Precision: 0.9001, Val Precision: 0.9014, Train Recall: 0.8937, Val Recall: 0.8638
# Epoch 74 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.56it/s]
# Epoch 74 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.27it/s]
# Epoch 74 Summary: Train Loss: 0.0955, Val Loss: 0.1352, Train Accuracy: 0.7462, Val Accuracy: 0.6828, Train IoU: 0.8039, Val IoU: 0.7849, Train Dice: 0.8909, Val Dice: 0.8794, Train Precision: 0.8933, Val Precision: 0.9140, Train Recall: 0.8886, Val Recall: 0.8474
# Epoch 75 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.71it/s]
# Epoch 75 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.47it/s]
# Epoch 75 Summary: Train Loss: 0.0853, Val Loss: 0.1335, Train Accuracy: 0.7730, Val Accuracy: 0.6828, Train IoU: 0.8122, Val IoU: 0.7907, Train Dice: 0.8963, Val Dice: 0.8831, Train Precision: 0.9003, Val Precision: 0.9032, Train Recall: 0.8925, Val Recall: 0.8639
# Epoch 76 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.51it/s]
# Epoch 76 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.77it/s]
# Epoch 76 Summary: Train Loss: 0.0848, Val Loss: 0.1315, Train Accuracy: 0.7732, Val Accuracy: 0.6828, Train IoU: 0.8144, Val IoU: 0.7939, Train Dice: 0.8975, Val Dice: 0.8851, Train Precision: 0.9023, Val Precision: 0.8963, Train Recall: 0.8929, Val Recall: 0.8742
# Epoch 77 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.71it/s]
# Epoch 77 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.65it/s]
# Epoch 77 Summary: Train Loss: 0.0841, Val Loss: 0.1362, Train Accuracy: 0.7750, Val Accuracy: 0.6828, Train IoU: 0.8172, Val IoU: 0.7880, Train Dice: 0.8992, Val Dice: 0.8814, Train Precision: 0.9047, Val Precision: 0.9090, Train Recall: 0.8937, Val Recall: 0.8554
# Epoch 78 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.71it/s]
# Epoch 78 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.36it/s]
# Epoch 78 Summary: Train Loss: 0.0851, Val Loss: 0.1348, Train Accuracy: 0.7730, Val Accuracy: 0.6828, Train IoU: 0.8116, Val IoU: 0.7898, Train Dice: 0.8959, Val Dice: 0.8826, Train Precision: 0.8992, Val Precision: 0.9029, Train Recall: 0.8926, Val Recall: 0.8631
# Epoch 79 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.69it/s]
# Epoch 79 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.91it/s]
# Epoch 79 Summary: Train Loss: 0.0890, Val Loss: 0.1342, Train Accuracy: 0.7620, Val Accuracy: 0.6828, Train IoU: 0.8101, Val IoU: 0.7884, Train Dice: 0.8948, Val Dice: 0.8817, Train Precision: 0.8978, Val Precision: 0.9086, Train Recall: 0.8919, Val Recall: 0.8563
# Epoch 80 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.29it/s]
# Epoch 80 - Validation: 100%|██████████| 2/2 [00:00<00:00,  9.63it/s]
# Epoch 80 Summary: Train Loss: 0.0884, Val Loss: 0.1312, Train Accuracy: 0.7637, Val Accuracy: 0.6828, Train IoU: 0.8099, Val IoU: 0.7919, Train Dice: 0.8947, Val Dice: 0.8839, Train Precision: 0.9001, Val Precision: 0.9031, Train Recall: 0.8895, Val Recall: 0.8654
# Epoch 81 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.28it/s]
# Epoch 81 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.53it/s]
# Epoch 81 Summary: Train Loss: 0.0919, Val Loss: 0.1318, Train Accuracy: 0.7546, Val Accuracy: 0.6828, Train IoU: 0.8190, Val IoU: 0.7932, Train Dice: 0.9003, Val Dice: 0.8846, Train Precision: 0.9057, Val Precision: 0.8977, Train Recall: 0.8950, Val Recall: 0.8719
# Epoch 82 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.77it/s]
# Epoch 82 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.72it/s]
# Epoch 82 Summary: Train Loss: 0.0918, Val Loss: 0.1338, Train Accuracy: 0.7546, Val Accuracy: 0.6828, Train IoU: 0.8176, Val IoU: 0.7941, Train Dice: 0.8995, Val Dice: 0.8852, Train Precision: 0.9058, Val Precision: 0.8941, Train Recall: 0.8932, Val Recall: 0.8765
# Epoch 83 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.54it/s]
# Epoch 83 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.19it/s]
# Epoch 83 Summary: Train Loss: 0.0845, Val Loss: 0.1348, Train Accuracy: 0.7744, Val Accuracy: 0.6828, Train IoU: 0.8121, Val IoU: 0.7879, Train Dice: 0.8963, Val Dice: 0.8814, Train Precision: 0.8976, Val Precision: 0.9057, Train Recall: 0.8951, Val Recall: 0.8583
# Epoch 84 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.65it/s]
# Epoch 84 - Validation: 100%|██████████| 2/2 [00:00<00:00,  9.48it/s]
# Epoch 84 Summary: Train Loss: 0.0844, Val Loss: 0.1392, Train Accuracy: 0.7744, Val Accuracy: 0.6828, Train IoU: 0.8133, Val IoU: 0.7802, Train Dice: 0.8969, Val Dice: 0.8765, Train Precision: 0.8997, Val Precision: 0.9173, Train Recall: 0.8941, Val Recall: 0.8392
# Epoch 85 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.64it/s]
# Epoch 85 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.00it/s]
# Epoch 85 Summary: Train Loss: 0.0955, Val Loss: 0.1311, Train Accuracy: 0.7462, Val Accuracy: 0.6828, Train IoU: 0.8056, Val IoU: 0.7905, Train Dice: 0.8920, Val Dice: 0.8829, Train Precision: 0.8962, Val Precision: 0.9038, Train Recall: 0.8880, Val Recall: 0.8630
# Epoch 86 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.55it/s]
# Epoch 86 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.87it/s]
# Epoch 86 Summary: Train Loss: 0.0854, Val Loss: 0.1318, Train Accuracy: 0.7730, Val Accuracy: 0.6828, Train IoU: 0.8110, Val IoU: 0.7921, Train Dice: 0.8955, Val Dice: 0.8840, Train Precision: 0.8995, Val Precision: 0.9028, Train Recall: 0.8920, Val Recall: 0.8660
# Epoch 87 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.73it/s]
# Epoch 87 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.35it/s]
# Epoch 87 Summary: Train Loss: 0.0956, Val Loss: 0.1369, Train Accuracy: 0.7462, Val Accuracy: 0.6828, Train IoU: 0.8056, Val IoU: 0.7774, Train Dice: 0.8921, Val Dice: 0.8747, Train Precision: 0.8970, Val Precision: 0.9220, Train Recall: 0.8874, Val Recall: 0.8320
# Epoch 88 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.66it/s]
# Epoch 88 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.81it/s]
# Epoch 88 Summary: Train Loss: 0.0880, Val Loss: 0.1321, Train Accuracy: 0.7651, Val Accuracy: 0.6828, Train IoU: 0.8189, Val IoU: 0.7898, Train Dice: 0.9001, Val Dice: 0.8825, Train Precision: 0.9053, Val Precision: 0.9068, Train Recall: 0.8952, Val Recall: 0.8596
# Epoch 89 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.63it/s]
# Epoch 89 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.52it/s]
# Epoch 89 Summary: Train Loss: 0.0846, Val Loss: 0.1330, Train Accuracy: 0.7744, Val Accuracy: 0.6828, Train IoU: 0.8071, Val IoU: 0.7884, Train Dice: 0.8931, Val Dice: 0.8816, Train Precision: 0.9009, Val Precision: 0.9062, Train Recall: 0.8854, Val Recall: 0.8584
# Epoch 90 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.53it/s]
# Epoch 90 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.76it/s]
# Epoch 90 Summary: Train Loss: 0.0953, Val Loss: 0.1380, Train Accuracy: 0.7462, Val Accuracy: 0.6828, Train IoU: 0.8060, Val IoU: 0.7784, Train Dice: 0.8922, Val Dice: 0.8754, Train Precision: 0.8944, Val Precision: 0.9202, Train Recall: 0.8901, Val Recall: 0.8346
# Epoch 91 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.61it/s]
# Epoch 91 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.18it/s]
# Epoch 91 Summary: Train Loss: 0.0934, Val Loss: 0.1323, Train Accuracy: 0.7500, Val Accuracy: 0.6828, Train IoU: 0.8109, Val IoU: 0.7890, Train Dice: 0.8954, Val Dice: 0.8820, Train Precision: 0.8984, Val Precision: 0.9052, Train Recall: 0.8924, Val Recall: 0.8601
# Epoch 92 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.58it/s]
# Epoch 92 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.84it/s]
# Epoch 92 Summary: Train Loss: 0.0938, Val Loss: 0.1324, Train Accuracy: 0.7491, Val Accuracy: 0.6828, Train IoU: 0.8139, Val IoU: 0.7961, Train Dice: 0.8973, Val Dice: 0.8864, Train Precision: 0.9041, Val Precision: 0.8778, Train Recall: 0.8906, Val Recall: 0.8953
# Saved Best Model with Dice: 0.8864
# Epoch 93 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.49it/s]
# Epoch 93 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.66it/s]
# Epoch 93 Summary: Train Loss: 0.0984, Val Loss: 0.1337, Train Accuracy: 0.7398, Val Accuracy: 0.6828, Train IoU: 0.8083, Val IoU: 0.7947, Train Dice: 0.8938, Val Dice: 0.8856, Train Precision: 0.9034, Val Precision: 0.8786, Train Recall: 0.8850, Val Recall: 0.8927
# Epoch 94 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.45it/s]
# Epoch 94 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.19it/s]
# Epoch 94 Summary: Train Loss: 0.0877, Val Loss: 0.1342, Train Accuracy: 0.7710, Val Accuracy: 0.6828, Train IoU: 0.8133, Val IoU: 0.7841, Train Dice: 0.8967, Val Dice: 0.8789, Train Precision: 0.9010, Val Precision: 0.9124, Train Recall: 0.8942, Val Recall: 0.8478
# Epoch 95 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.59it/s]
# Epoch 95 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.61it/s]
# Epoch 95 Summary: Train Loss: 0.0928, Val Loss: 0.1408, Train Accuracy: 0.7546, Val Accuracy: 0.6828, Train IoU: 0.8184, Val IoU: 0.7854, Train Dice: 0.8999, Val Dice: 0.8798, Train Precision: 0.9020, Val Precision: 0.9045, Train Recall: 0.8979, Val Recall: 0.8564
# Epoch 96 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.51it/s]
# Epoch 96 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.18it/s]
# Epoch 96 Summary: Train Loss: 0.0984, Val Loss: 0.1377, Train Accuracy: 0.7398, Val Accuracy: 0.6828, Train IoU: 0.8115, Val IoU: 0.7881, Train Dice: 0.8959, Val Dice: 0.8815, Train Precision: 0.8994, Val Precision: 0.9027, Train Recall: 0.8928, Val Recall: 0.8613
# Epoch 97 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.32it/s]
# Epoch 97 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.51it/s]
# Epoch 97 Summary: Train Loss: 0.0886, Val Loss: 0.1432, Train Accuracy: 0.7651, Val Accuracy: 0.6827, Train IoU: 0.8179, Val IoU: 0.7713, Train Dice: 0.8996, Val Dice: 0.8708, Train Precision: 0.9035, Val Precision: 0.9279, Train Recall: 0.8959, Val Recall: 0.8204
# Epoch 98 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.47it/s]
# Epoch 98 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.25it/s]
# Epoch 98 Summary: Train Loss: 0.0850, Val Loss: 0.1368, Train Accuracy: 0.7732, Val Accuracy: 0.6828, Train IoU: 0.8133, Val IoU: 0.7831, Train Dice: 0.8969, Val Dice: 0.8783, Train Precision: 0.8993, Val Precision: 0.9164, Train Recall: 0.8945, Val Recall: 0.8433
# Epoch 99 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.57it/s]
# Epoch 99 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.53it/s]
# Epoch 99 Summary: Train Loss: 0.0886, Val Loss: 0.1336, Train Accuracy: 0.7637, Val Accuracy: 0.6828, Train IoU: 0.8120, Val IoU: 0.7917, Train Dice: 0.8961, Val Dice: 0.8837, Train Precision: 0.8988, Val Precision: 0.9048, Train Recall: 0.8935, Val Recall: 0.8636
# Epoch 100 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.52it/s]
# Epoch 100 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.38it/s]
# Epoch 100 Summary: Train Loss: 0.0840, Val Loss: 0.1364, Train Accuracy: 0.7762, Val Accuracy: 0.6828, Train IoU: 0.8158, Val IoU: 0.7873, Train Dice: 0.8985, Val Dice: 0.8810, Train Precision: 0.9024, Val Precision: 0.9099, Train Recall: 0.8949, Val Recall: 0.8538
# Epoch 101 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.54it/s]
# Epoch 101 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.96it/s]
# Epoch 101 Summary: Train Loss: 0.0837, Val Loss: 0.1334, Train Accuracy: 0.7762, Val Accuracy: 0.6828, Train IoU: 0.8162, Val IoU: 0.7924, Train Dice: 0.8987, Val Dice: 0.8841, Train Precision: 0.9033, Val Precision: 0.9008, Train Recall: 0.8943, Val Recall: 0.8681
# Epoch 102 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.56it/s]
# Epoch 102 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.90it/s]
# Epoch 102 Summary: Train Loss: 0.0842, Val Loss: 0.1348, Train Accuracy: 0.7750, Val Accuracy: 0.6828, Train IoU: 0.8182, Val IoU: 0.7883, Train Dice: 0.8998, Val Dice: 0.8816, Train Precision: 0.9073, Val Precision: 0.9079, Train Recall: 0.8925, Val Recall: 0.8568
# Epoch 103 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.41it/s]
# Epoch 103 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.98it/s]
# Epoch 103 Summary: Train Loss: 0.0852, Val Loss: 0.1310, Train Accuracy: 0.7730, Val Accuracy: 0.6828, Train IoU: 0.8122, Val IoU: 0.7929, Train Dice: 0.8964, Val Dice: 0.8845, Train Precision: 0.8998, Val Precision: 0.9024, Train Recall: 0.8932, Val Recall: 0.8672
# Epoch 104 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.44it/s]
# Epoch 104 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.88it/s]
# Epoch 104 Summary: Train Loss: 0.0851, Val Loss: 0.1314, Train Accuracy: 0.7727, Val Accuracy: 0.6828, Train IoU: 0.8100, Val IoU: 0.7963, Train Dice: 0.8948, Val Dice: 0.8866, Train Precision: 0.8978, Val Precision: 0.8932, Train Recall: 0.8921, Val Recall: 0.8801
# Saved Best Model with Dice: 0.8866
# Epoch 105 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.57it/s]
# Epoch 105 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.76it/s]
# Epoch 105 Summary: Train Loss: 0.0841, Val Loss: 0.1345, Train Accuracy: 0.7750, Val Accuracy: 0.6828, Train IoU: 0.8179, Val IoU: 0.7923, Train Dice: 0.8996, Val Dice: 0.8841, Train Precision: 0.9027, Val Precision: 0.9029, Train Recall: 0.8967, Val Recall: 0.8661
# Epoch 106 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.47it/s]
# Epoch 106 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.36it/s]
# Epoch 106 Summary: Train Loss: 0.0840, Val Loss: 0.1313, Train Accuracy: 0.7750, Val Accuracy: 0.6828, Train IoU: 0.8194, Val IoU: 0.7949, Train Dice: 0.9006, Val Dice: 0.8857, Train Precision: 0.9031, Val Precision: 0.8986, Train Recall: 0.8982, Val Recall: 0.8731
# Epoch 107 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.41it/s]
# Epoch 107 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.22it/s]
# Epoch 107 Summary: Train Loss: 0.0896, Val Loss: 0.1323, Train Accuracy: 0.7600, Val Accuracy: 0.6828, Train IoU: 0.8157, Val IoU: 0.7885, Train Dice: 0.8984, Val Dice: 0.8817, Train Precision: 0.9021, Val Precision: 0.9104, Train Recall: 0.8948, Val Recall: 0.8547
# Epoch 108 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.43it/s]
# Epoch 108 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.15it/s]
# Epoch 108 Summary: Train Loss: 0.0848, Val Loss: 0.1326, Train Accuracy: 0.7730, Val Accuracy: 0.6828, Train IoU: 0.8111, Val IoU: 0.7905, Train Dice: 0.8956, Val Dice: 0.8830, Train Precision: 0.8996, Val Precision: 0.9065, Train Recall: 0.8916, Val Recall: 0.8607
# Epoch 109 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.40it/s]
# Epoch 109 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.76it/s]
# Epoch 109 Summary: Train Loss: 0.0909, Val Loss: 0.1337, Train Accuracy: 0.7564, Val Accuracy: 0.6828, Train IoU: 0.8150, Val IoU: 0.7883, Train Dice: 0.8978, Val Dice: 0.8816, Train Precision: 0.9011, Val Precision: 0.9092, Train Recall: 0.8945, Val Recall: 0.8556
# Epoch 110 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.56it/s]
# Epoch 110 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.41it/s]
# Epoch 110 Summary: Train Loss: 0.0839, Val Loss: 0.1334, Train Accuracy: 0.7750, Val Accuracy: 0.6828, Train IoU: 0.8185, Val IoU: 0.7876, Train Dice: 0.9000, Val Dice: 0.8812, Train Precision: 0.9035, Val Precision: 0.9088, Train Recall: 0.8965, Val Recall: 0.8552
# Epoch 111 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.02it/s]
# Epoch 111 - Validation: 100%|██████████| 2/2 [00:00<00:00,  9.61it/s]
# Epoch 111 Summary: Train Loss: 0.0974, Val Loss: 0.1304, Train Accuracy: 0.7398, Val Accuracy: 0.6828, Train IoU: 0.8103, Val IoU: 0.7934, Train Dice: 0.8950, Val Dice: 0.8848, Train Precision: 0.9007, Val Precision: 0.9003, Train Recall: 0.8895, Val Recall: 0.8697
# Epoch 112 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.23it/s]
# Epoch 112 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.45it/s]
# Epoch 112 Summary: Train Loss: 0.0973, Val Loss: 0.1302, Train Accuracy: 0.7398, Val Accuracy: 0.6828, Train IoU: 0.8116, Val IoU: 0.7924, Train Dice: 0.8959, Val Dice: 0.8841, Train Precision: 0.8989, Val Precision: 0.9013, Train Recall: 0.8930, Val Recall: 0.8676
# Epoch 113 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.44it/s]
# Epoch 113 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.58it/s]
# Epoch 113 Summary: Train Loss: 0.0938, Val Loss: 0.1310, Train Accuracy: 0.7491, Val Accuracy: 0.6828, Train IoU: 0.8134, Val IoU: 0.7911, Train Dice: 0.8969, Val Dice: 0.8833, Train Precision: 0.8991, Val Precision: 0.9027, Train Recall: 0.8949, Val Recall: 0.8647
# Epoch 114 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.38it/s]
# Epoch 114 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.49it/s]
# Epoch 114 Summary: Train Loss: 0.0913, Val Loss: 0.1317, Train Accuracy: 0.7553, Val Accuracy: 0.6828, Train IoU: 0.8147, Val IoU: 0.7909, Train Dice: 0.8977, Val Dice: 0.8832, Train Precision: 0.9035, Val Precision: 0.9022, Train Recall: 0.8920, Val Recall: 0.8651
# Epoch 115 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.45it/s]
# Epoch 115 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.25it/s]
# Epoch 115 Summary: Train Loss: 0.0927, Val Loss: 0.1305, Train Accuracy: 0.7521, Val Accuracy: 0.6828, Train IoU: 0.8136, Val IoU: 0.7944, Train Dice: 0.8971, Val Dice: 0.8854, Train Precision: 0.9026, Val Precision: 0.8964, Train Recall: 0.8918, Val Recall: 0.8746
# Epoch 116 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.43it/s]
# Epoch 116 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.64it/s]
# Epoch 116 Summary: Train Loss: 0.0925, Val Loss: 0.1296, Train Accuracy: 0.7527, Val Accuracy: 0.6828, Train IoU: 0.8126, Val IoU: 0.7957, Train Dice: 0.8964, Val Dice: 0.8862, Train Precision: 0.9008, Val Precision: 0.8947, Train Recall: 0.8922, Val Recall: 0.8778
# Epoch 117 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.34it/s]
# Epoch 117 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.15it/s]
# Epoch 117 Summary: Train Loss: 0.0925, Val Loss: 0.1378, Train Accuracy: 0.7546, Val Accuracy: 0.6828, Train IoU: 0.8159, Val IoU: 0.7788, Train Dice: 0.8983, Val Dice: 0.8756, Train Precision: 0.9011, Val Precision: 0.9220, Train Recall: 0.8960, Val Recall: 0.8337
# Epoch 118 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.41it/s]
# Epoch 118 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.71it/s]
# Epoch 118 Summary: Train Loss: 0.0916, Val Loss: 0.1334, Train Accuracy: 0.7564, Val Accuracy: 0.6828, Train IoU: 0.8148, Val IoU: 0.7820, Train Dice: 0.8979, Val Dice: 0.8776, Train Precision: 0.8987, Val Precision: 0.9193, Train Recall: 0.8973, Val Recall: 0.8395
# Epoch 119 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.31it/s]
# Epoch 119 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.44it/s]
# ...
# Epoch 162 Summary: Train Loss: 0.0923, Val Loss: 0.1300, Train Accuracy: 0.7521, Val Accuracy: 0.6828, Train IoU: 0.8168, Val IoU: 0.7922, Train Dice: 0.8990, Val Dice: 0.8840, Train Precision: 0.9024, Val Precision: 0.9033, Train Recall: 0.8956, Val Recall: 0.8656
# Epoch 163 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.41it/s]
# Epoch 163 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.99it/s]
# Epoch 163 Summary: Train Loss: 0.0839, Val Loss: 0.1303, Train Accuracy: 0.7744, Val Accuracy: 0.6828, Train IoU: 0.8127, Val IoU: 0.7935, Train Dice: 0.8966, Val Dice: 0.8848, Train Precision: 0.9001, Val Precision: 0.8994, Train Recall: 0.8931, Val Recall: 0.8707
# Epoch 164 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.24it/s]
# Epoch 164 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.86it/s]
# Epoch 164 Summary: Train Loss: 0.0972, Val Loss: 0.1296, Train Accuracy: 0.7398, Val Accuracy: 0.6828, Train IoU: 0.8124, Val IoU: 0.7958, Train Dice: 0.8963, Val Dice: 0.8863, Train Precision: 0.9012, Val Precision: 0.8934, Train Recall: 0.8916, Val Recall: 0.8792
# Epoch 165 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.24it/s]
# Epoch 165 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.43it/s]
# Epoch 165 Summary: Train Loss: 0.0882, Val Loss: 0.1296, Train Accuracy: 0.7641, Val Accuracy: 0.6828, Train IoU: 0.8209, Val IoU: 0.7960, Train Dice: 0.9013, Val Dice: 0.8864, Train Precision: 0.9056, Val Precision: 0.8928, Train Recall: 0.8973, Val Recall: 0.8801
# Epoch 166 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.32it/s]
# Epoch 166 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.61it/s]
# Epoch 166 Summary: Train Loss: 0.0952, Val Loss: 0.1342, Train Accuracy: 0.7462, Val Accuracy: 0.6828, Train IoU: 0.8066, Val IoU: 0.7908, Train Dice: 0.8926, Val Dice: 0.8832, Train Precision: 0.8955, Val Precision: 0.9075, Train Recall: 0.8898, Val Recall: 0.8601
# Epoch 167 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.38it/s]
# Epoch 167 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.09it/s]
# Epoch 167 Summary: Train Loss: 0.0837, Val Loss: 0.1299, Train Accuracy: 0.7762, Val Accuracy: 0.6828, Train IoU: 0.8179, Val IoU: 0.7958, Train Dice: 0.8997, Val Dice: 0.8862, Train Precision: 0.9017, Val Precision: 0.8972, Train Recall: 0.8979, Val Recall: 0.8755
# Epoch 168 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.33it/s]
# Epoch 168 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.40it/s]
# Epoch 168 Summary: Train Loss: 0.0848, Val Loss: 0.1337, Train Accuracy: 0.7727, Val Accuracy: 0.6828, Train IoU: 0.8099, Val IoU: 0.7906, Train Dice: 0.8948, Val Dice: 0.8830, Train Precision: 0.9016, Val Precision: 0.9058, Train Recall: 0.8882, Val Recall: 0.8614
# Epoch 169 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.29it/s]
# Epoch 169 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.14it/s]
# Epoch 169 Summary: Train Loss: 0.0907, Val Loss: 0.1338, Train Accuracy: 0.7564, Val Accuracy: 0.6828, Train IoU: 0.8175, Val IoU: 0.7889, Train Dice: 0.8995, Val Dice: 0.8820, Train Precision: 0.9020, Val Precision: 0.9093, Train Recall: 0.8971, Val Recall: 0.8562
# Epoch 170 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.29it/s]
# Epoch 170 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.12it/s]
# Epoch 170 Summary: Train Loss: 0.0915, Val Loss: 0.1334, Train Accuracy: 0.7546, Val Accuracy: 0.6828, Train IoU: 0.8189, Val IoU: 0.7857, Train Dice: 0.9002, Val Dice: 0.8799, Train Precision: 0.9045, Val Precision: 0.9138, Train Recall: 0.8960, Val Recall: 0.8485
# Epoch 171 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.14it/s]
# Epoch 171 - Validation: 100%|██████████| 2/2 [00:00<00:00,  9.85it/s]
# Epoch 171 Summary: Train Loss: 0.0892, Val Loss: 0.1349, Train Accuracy: 0.7606, Val Accuracy: 0.6828, Train IoU: 0.8172, Val IoU: 0.7845, Train Dice: 0.8993, Val Dice: 0.8792, Train Precision: 0.9010, Val Precision: 0.9156, Train Recall: 0.8976, Val Recall: 0.8456
# Epoch 172 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.28it/s]
# Epoch 172 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.11it/s]
# Epoch 172 Summary: Train Loss: 0.0846, Val Loss: 0.1339, Train Accuracy: 0.7727, Val Accuracy: 0.6828, Train IoU: 0.8085, Val IoU: 0.7874, Train Dice: 0.8940, Val Dice: 0.8810, Train Precision: 0.8998, Val Precision: 0.9101, Train Recall: 0.8884, Val Recall: 0.8538
# Epoch 173 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.11it/s]
# Epoch 173 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.56it/s]
# Epoch 173 Summary: Train Loss: 0.0947, Val Loss: 0.1312, Train Accuracy: 0.7462, Val Accuracy: 0.6828, Train IoU: 0.8079, Val IoU: 0.7941, Train Dice: 0.8935, Val Dice: 0.8852, Train Precision: 0.8947, Val Precision: 0.8995, Train Recall: 0.8922, Val Recall: 0.8713
# Epoch 174 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.23it/s]
# Epoch 174 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.54it/s]
# Epoch 174 Summary: Train Loss: 0.0929, Val Loss: 0.1289, Train Accuracy: 0.7500, Val Accuracy: 0.6828, Train IoU: 0.8098, Val IoU: 0.7979, Train Dice: 0.8947, Val Dice: 0.8875, Train Precision: 0.8999, Val Precision: 0.8907, Train Recall: 0.8896, Val Recall: 0.8844
# Saved Best Model with Dice: 0.8875
# Epoch 175 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.33it/s]
# Epoch 175 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.67it/s]
# Epoch 175 Summary: Train Loss: 0.0876, Val Loss: 0.1287, Train Accuracy: 0.7641, Val Accuracy: 0.6828, Train IoU: 0.8205, Val IoU: 0.7985, Train Dice: 0.9010, Val Dice: 0.8879, Train Precision: 0.9055, Val Precision: 0.8861, Train Recall: 0.8965, Val Recall: 0.8898
# Saved Best Model with Dice: 0.8879
# Epoch 176 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.34it/s]
# Epoch 176 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.17it/s]
# Epoch 176 Summary: Train Loss: 0.0840, Val Loss: 0.1308, Train Accuracy: 0.7744, Val Accuracy: 0.6828, Train IoU: 0.8106, Val IoU: 0.7927, Train Dice: 0.8953, Val Dice: 0.8843, Train Precision: 0.8974, Val Precision: 0.9023, Train Recall: 0.8934, Val Recall: 0.8670
# Epoch 177 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.41it/s]
# Epoch 177 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.62it/s]
# Epoch 177 Summary: Train Loss: 0.0842, Val Loss: 0.1334, Train Accuracy: 0.7732, Val Accuracy: 0.6828, Train IoU: 0.8164, Val IoU: 0.7887, Train Dice: 0.8988, Val Dice: 0.8818, Train Precision: 0.9033, Val Precision: 0.9104, Train Recall: 0.8943, Val Recall: 0.8550
# Epoch 178 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.34it/s]
# Epoch 178 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.32it/s]
# Epoch 178 Summary: Train Loss: 0.0947, Val Loss: 0.1311, Train Accuracy: 0.7462, Val Accuracy: 0.6828, Train IoU: 0.8079, Val IoU: 0.7921, Train Dice: 0.8934, Val Dice: 0.8839, Train Precision: 0.8974, Val Precision: 0.9048, Train Recall: 0.8894, Val Recall: 0.8640
# Epoch 179 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.28it/s]
# Epoch 179 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.59it/s]
# Epoch 179 Summary: Train Loss: 0.0878, Val Loss: 0.1310, Train Accuracy: 0.7637, Val Accuracy: 0.6828, Train IoU: 0.8096, Val IoU: 0.7917, Train Dice: 0.8946, Val Dice: 0.8837, Train Precision: 0.8989, Val Precision: 0.9068, Train Recall: 0.8904, Val Recall: 0.8617
# Epoch 180 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.29it/s]
# Epoch 180 - Validation: 100%|██████████| 2/2 [00:00<00:00,  9.46it/s]
# Epoch 180 Summary: Train Loss: 0.0877, Val Loss: 0.1301, Train Accuracy: 0.7637, Val Accuracy: 0.6828, Train IoU: 0.8128, Val IoU: 0.7936, Train Dice: 0.8967, Val Dice: 0.8849, Train Precision: 0.9007, Val Precision: 0.9019, Train Recall: 0.8928, Val Recall: 0.8685
# Epoch 181 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.37it/s]
# Epoch 181 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.69it/s]
# Epoch 181 Summary: Train Loss: 0.0832, Val Loss: 0.1310, Train Accuracy: 0.7762, Val Accuracy: 0.6828, Train IoU: 0.8184, Val IoU: 0.7945, Train Dice: 0.8999, Val Dice: 0.8855, Train Precision: 0.9035, Val Precision: 0.8996, Train Recall: 0.8964, Val Recall: 0.8717
# Epoch 182 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.30it/s]
# Epoch 182 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.25it/s]
# Epoch 182 Summary: Train Loss: 0.0948, Val Loss: 0.1297, Train Accuracy: 0.7462, Val Accuracy: 0.6828, Train IoU: 0.8072, Val IoU: 0.7957, Train Dice: 0.8930, Val Dice: 0.8862, Train Precision: 0.8988, Val Precision: 0.8961, Train Recall: 0.8873, Val Recall: 0.8765
# Epoch 183 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.41it/s]
# Epoch 183 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.35it/s]
# Epoch 183 Summary: Train Loss: 0.0926, Val Loss: 0.1292, Train Accuracy: 0.7521, Val Accuracy: 0.6828, Train IoU: 0.8135, Val IoU: 0.7994, Train Dice: 0.8969, Val Dice: 0.8885, Train Precision: 0.9015, Val Precision: 0.8828, Train Recall: 0.8928, Val Recall: 0.8942
# Saved Best Model with Dice: 0.8885
# Epoch 184 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.26it/s]
# Epoch 184 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.84it/s]
# Epoch 184 Summary: Train Loss: 0.0835, Val Loss: 0.1335, Train Accuracy: 0.7762, Val Accuracy: 0.6828, Train IoU: 0.8191, Val IoU: 0.7964, Train Dice: 0.9004, Val Dice: 0.8866, Train Precision: 0.9018, Val Precision: 0.8960, Train Recall: 0.8991, Val Recall: 0.8775
# Epoch 185 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.33it/s]
# Epoch 185 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.51it/s]
# Epoch 185 Summary: Train Loss: 0.0881, Val Loss: 0.1287, Train Accuracy: 0.7637, Val Accuracy: 0.6828, Train IoU: 0.8111, Val IoU: 0.7970, Train Dice: 0.8956, Val Dice: 0.8870, Train Precision: 0.8981, Val Precision: 0.8973, Train Recall: 0.8932, Val Recall: 0.8769
# Epoch 186 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.26it/s]
# Epoch 186 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.14it/s]
# Epoch 186 Summary: Train Loss: 0.0846, Val Loss: 0.1310, Train Accuracy: 0.7725, Val Accuracy: 0.6828, Train IoU: 0.8184, Val IoU: 0.7893, Train Dice: 0.8999, Val Dice: 0.8822, Train Precision: 0.9051, Val Precision: 0.9122, Train Recall: 0.8948, Val Recall: 0.8541
# Epoch 187 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.22it/s]
# Epoch 187 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.78it/s]
# Epoch 187 Summary: Train Loss: 0.0947, Val Loss: 0.1334, Train Accuracy: 0.7462, Val Accuracy: 0.6828, Train IoU: 0.8084, Val IoU: 0.7838, Train Dice: 0.8938, Val Dice: 0.8787, Train Precision: 0.8970, Val Precision: 0.9185, Train Recall: 0.8906, Val Recall: 0.8422
# Epoch 188 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.35it/s]
# Epoch 188 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.82it/s]
# Epoch 188 Summary: Train Loss: 0.0846, Val Loss: 0.1306, Train Accuracy: 0.7730, Val Accuracy: 0.6828, Train IoU: 0.8132, Val IoU: 0.7908, Train Dice: 0.8969, Val Dice: 0.8831, Train Precision: 0.8989, Val Precision: 0.9093, Train Recall: 0.8950, Val Recall: 0.8584
# Epoch 189 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.18it/s]
# Epoch 189 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.20it/s]
# Epoch 189 Summary: Train Loss: 0.0877, Val Loss: 0.1301, Train Accuracy: 0.7641, Val Accuracy: 0.6828, Train IoU: 0.8234, Val IoU: 0.7930, Train Dice: 0.9028, Val Dice: 0.8845, Train Precision: 0.9077, Val Precision: 0.9046, Train Recall: 0.8980, Val Recall: 0.8653
# Epoch 190 - Training: 100%|██████████| 7/7 [00:00<00:00,  7.98it/s]
# Epoch 190 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.76it/s]
# Epoch 190 Summary: Train Loss: 0.0892, Val Loss: 0.1305, Train Accuracy: 0.7600, Val Accuracy: 0.6828, Train IoU: 0.8184, Val IoU: 0.7930, Train Dice: 0.9000, Val Dice: 0.8845, Train Precision: 0.9028, Val Precision: 0.9044, Train Recall: 0.8972, Val Recall: 0.8655
# Epoch 191 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.15it/s]
# Epoch 191 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.06it/s]
# Epoch 191 Summary: Train Loss: 0.0872, Val Loss: 0.1299, Train Accuracy: 0.7651, Val Accuracy: 0.6828, Train IoU: 0.8201, Val IoU: 0.7931, Train Dice: 0.9009, Val Dice: 0.8846, Train Precision: 0.9051, Val Precision: 0.9048, Train Recall: 0.8968, Val Recall: 0.8652
# Epoch 192 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.23it/s]
# Epoch 192 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.25it/s]
# Epoch 192 Summary: Train Loss: 0.0875, Val Loss: 0.1307, Train Accuracy: 0.7641, Val Accuracy: 0.6828, Train IoU: 0.8208, Val IoU: 0.7925, Train Dice: 0.9012, Val Dice: 0.8842, Train Precision: 0.9041, Val Precision: 0.9047, Train Recall: 0.8983, Val Recall: 0.8646
# Epoch 193 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.36it/s]
# Epoch 193 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.16it/s]
# Epoch 193 Summary: Train Loss: 0.0922, Val Loss: 0.1289, Train Accuracy: 0.7521, Val Accuracy: 0.6828, Train IoU: 0.8144, Val IoU: 0.7954, Train Dice: 0.8977, Val Dice: 0.8860, Train Precision: 0.9024, Val Precision: 0.9002, Train Recall: 0.8931, Val Recall: 0.8723
# Epoch 194 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.11it/s]
# Epoch 194 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.36it/s]
# Epoch 194 Summary: Train Loss: 0.0922, Val Loss: 0.1304, Train Accuracy: 0.7521, Val Accuracy: 0.6828, Train IoU: 0.8141, Val IoU: 0.7919, Train Dice: 0.8974, Val Dice: 0.8838, Train Precision: 0.9010, Val Precision: 0.9063, Train Recall: 0.8939, Val Recall: 0.8624
# Epoch 195 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.31it/s]
# Epoch 195 - Validation: 100%|██████████| 2/2 [00:00<00:00, 10.93it/s]
# Epoch 195 Summary: Train Loss: 0.0836, Val Loss: 0.1308, Train Accuracy: 0.7750, Val Accuracy: 0.6828, Train IoU: 0.8191, Val IoU: 0.7923, Train Dice: 0.9002, Val Dice: 0.8841, Train Precision: 0.9026, Val Precision: 0.9050, Train Recall: 0.8979, Val Recall: 0.8641
# Epoch 196 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.30it/s]
# Epoch 196 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.32it/s]
# Epoch 196 Summary: Train Loss: 0.0922, Val Loss: 0.1293, Train Accuracy: 0.7521, Val Accuracy: 0.6828, Train IoU: 0.8153, Val IoU: 0.7957, Train Dice: 0.8982, Val Dice: 0.8862, Train Precision: 0.9030, Val Precision: 0.8979, Train Recall: 0.8934, Val Recall: 0.8749
# Epoch 197 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.28it/s]
# Epoch 197 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.34it/s]
# Epoch 197 Summary: Train Loss: 0.0991, Val Loss: 0.1303, Train Accuracy: 0.7356, Val Accuracy: 0.6828, Train IoU: 0.8066, Val IoU: 0.7968, Train Dice: 0.8924, Val Dice: 0.8869, Train Precision: 0.8956, Val Precision: 0.8967, Train Recall: 0.8892, Val Recall: 0.8773
# Epoch 198 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.21it/s]
# Epoch 198 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.27it/s]
# Epoch 198 Summary: Train Loss: 0.0972, Val Loss: 0.1269, Train Accuracy: 0.7398, Val Accuracy: 0.6828, Train IoU: 0.8133, Val IoU: 0.7978, Train Dice: 0.8968, Val Dice: 0.8875, Train Precision: 0.9013, Val Precision: 0.8929, Train Recall: 0.8925, Val Recall: 0.8822
# Epoch 199 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.25it/s]
# Epoch 199 - Validation: 100%|██████████| 2/2 [00:00<00:00,  9.80it/s]
# Epoch 199 Summary: Train Loss: 0.0918, Val Loss: 0.1314, Train Accuracy: 0.7553, Val Accuracy: 0.6828, Train IoU: 0.8153, Val IoU: 0.7915, Train Dice: 0.8979, Val Dice: 0.8836, Train Precision: 0.9033, Val Precision: 0.9030, Train Recall: 0.8929, Val Recall: 0.8650
# Epoch 200 - Training: 100%|██████████| 7/7 [00:00<00:00,  8.33it/s]
# Epoch 200 - Validation: 100%|██████████| 2/2 [00:00<00:00, 11.19it/s]
# Epoch 200 Summary: Train Loss: 0.0884, Val Loss: 0.1299, Train Accuracy: 0.7637, Val Accuracy: 0.6828, Train IoU: 0.8139, Val IoU: 0.7933, Train Dice: 0.8973, Val Dice: 0.8847, Train Precision: 0.8977, Val Precision: 0.9017, Train Recall: 0.8971, Val Recall: 0.8684
# Evaluating:   0%|          | 0/8 [00:00<?, ?it/s]
# Evaluating: 100%|██████████| 8/8 [00:02<00:00,  3.79it/s]
# Average Evaluation Loss: 0.0954
# Average IoU: 0.8032
# Average Dice Coefficient: 0.8907
# Average Accuracy: 0.7453
# Average Precision: 0.8932
# Average Recall: 0.8882
